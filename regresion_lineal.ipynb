# %%
# Cargamos las librerias necesarias 

import matplotlib.pyplot as plt
from sklearn import linear_model # usando sklear para saber los valores optimos
import seaborn as sns
import numpy as np
import pandas as pd
import os

# %%
# Cargamos en la version llamada data la informacion del CSV

dataRegresionLineal = pd.read_csv("C:/Users/HP 1000 NOTEBOOK PC/OneDrive/Desktop/UNAD_INGENIERIA DE SISTEMAS/PERIODO V/ANALISIS DE DATOS/FASE 2/data.csv")

# %%
# Desplegamos el archivo 
dataRegresionLineal.head(4)
# Out:
#    metro  precio
# 0      5     375
# 1     15     487
# 2     20     450
# 3     25     500

# %%
# grafica de la recta
dataRegresionLineal.plot.scatter(x="metro", y="precio")
plt.show()

# %%
# Regresión Lineal
Regresion = linear_model.LinearRegression()

# %%
# Se agregan los datos en un Array o Vector
metros = dataRegresionLineal["metro"].values.reshape((-1,1))

# %%
# Se crea el modelo
modelo = Regresion.fit(metros, dataRegresionLineal["precio"])

# Se importa la interseccion
print("Interseccion (b)", modelo.intercept_)

# Se importa la pendiente
print("Pendiente (m)", modelo.coef_)
# Out:
# Interseccion (b) 361.25714285714287
# Pendiente (m) [5.64571429]

# %%
# Se define la entrada y las predicciones aprtil de los modelos de predicion 
entrada = [[5],[10],[20],[25]]
predicciones = modelo.predict(entrada)
print(predicciones)
# Out:
# [389.48571429 417.71428571 474.17142857 502.4       ]

# %%
# Graficamos
dataRegresionLineal.plot.scatter(x = "metro", y = "precio", label = "Datos Originales")
plt.scatter(entrada, predicciones, color = "yellow")
plt.plot(entrada, predicciones, color = "green", label = "Linea de Regresión")
plt.title("Grafica Regresión lineal")
plt.xlabel("metro")
plt.ylabel("precio")
plt.legend()
plt.show()
